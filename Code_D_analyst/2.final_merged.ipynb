# %% [markdown]
# This algoritm work for make a join final from all datasets that Neg and Val

# %% [markdown]
# # 1.LIBRARIES

# %%
import os
import pandas as pd

# %% [markdown]
# # 2. lOCAL VAIRABLES

# %%
#Variables globales
#Nombre del dataframe final
nombre_merged = "mer_sub_neg_2018_2024"
# Definir la ruta donde se guardará el archivo Excel basado en la variable nombre_merged
output_name = f"{nombre_merged}.xlsx"
#output_path = os.path.join(r"C:/Users/crist/OneDrive - Corporación Universitaria Remington UNIREMINGTON/Estudio/Ciencia de datos/Lumethik/eps-data-solutions/data/processed/", output_name)
output_path = os.path.join(r"C:\Users\carlo\Downloads", output_name)

# %% [markdown]
# # 3.READING A FOLDER WITH DENIED OR VALIDATED DATA

# %%
# Función para solicitar la ruta de la carpeta al usuario
def obtener_ruta_carpeta():
    # Solicitar la ruta de la carpeta al usuario
    folder_path = input('Por favor, ingresa la ruta de la carpeta (incluyendo las comillas si están presentes): ')
    
    # Eliminar las comillas dobles alrededor de la ruta, si las hay
    folder_path = folder_path.strip('"')
    
    # Reemplazar las barras invertidas con barras normales
    folder_path = folder_path.replace("\\", "/")
    
    return folder_path  # Retorna la ruta corregida

# Función para leer los archivos y almacenarlos en un diccionario de DataFrames
def cargar_archivos_a_dataframe(folder_path):
    dataframes = {}
    
    # Itera sobre todos los archivos en la carpeta
    for i, filename in enumerate(os.listdir(folder_path), start=1):
        file_path = os.path.join(folder_path, filename)  # Construye la ruta completa
        
        try:
            if filename.endswith(".NEG"):  # Para archivos .NEG
                df = pd.read_csv(file_path, sep=",", encoding="latin-1", header=None)
                df.columns = [f"col_{j+1}" for j in range(df.shape[1])]  # Asigna nombres de columnas numerados
            elif filename.endswith(".csv"):  # Para archivos .csv
                df = pd.read_csv(file_path, encoding="utf-8")
            elif filename.endswith(".xlsx"):  # Para archivos .xlsx
                df = pd.read_excel(file_path, engine='openpyxl')
            else:
                print(f"Archivo {filename} no es compatible y será ignorado.")
                continue
            
            # Almacena el DataFrame en el diccionario con un nombre dinámico
            dataframes[f"df_{i}"] = df
            print(f"Archivo {filename} cargado como df_{i}")
        except Exception as e:
            print(f"No se pudo leer el archivo {filename}: {e}")
    
    return dataframes

# Función para mostrar las primeras filas de los DataFrames cargados
def mostrar_primeras_filas(dataframes):
    # Mostrar las primeras filas de los DataFrames para verificar
    for name, df in dataframes.items():
        print(f"Primeras filas de {name}:")
        print(df.head())
        break  # Muestra solo el primer DataFrame como ejemplo

# Llamada a la función para obtener la ruta
ruta = obtener_ruta_carpeta()
print(f"La ruta ingresada es: {ruta}")

# Llamada a la función para cargar los archivos en un diccionario de DataFrames
dataframes = cargar_archivos_a_dataframe(ruta)

# Llamada a la función para mostrar las primeras filas de los DataFrames cargados
mostrar_primeras_filas(dataframes)
# Out:
# Por favor, ingresa la ruta de la carpeta (incluyendo las comillas si están presentes):  "C:\Users\carlo\OneDrive\Documentos\dataP\Mergeds-018-024"
# La ruta ingresada es: C:/Users/carlo/OneDrive/Documentos/dataP/Mergeds-018-024
# Archivo neg_all_2018.xlsx cargado como df_1
# Archivo neg_all_2019.xlsx cargado como df_2
# Archivo neg_all_2020.xlsx cargado como df_3
# Archivo neg_all_2021.xlsx cargado como df_4
# Archivo neg_all_2022.xlsx cargado como df_5
# Archivo neg_all_2023.xlsx cargado como df_6
# Archivo neg_all_2024.xlsx cargado como df_7
# Primeras filas de df_1:
#   cod_reg tip_doc        doc    fech_nac  dep  mun  nov    fech_nov  \
# 0  EPS025      CN  140637155  14/07/2017   85    1  N01  24/07/2017
# 1  EPS025      CN  131329379  13/08/2017   85  440  N01  31/08/2017
# 2  EPS025      CN  141596996  19/09/2017   85  136  N09  20/09/2017
# 3  EPS025      CN  128098179  18/05/2015   85  410  N14  10/10/2017
# 4  EPS025      CN  128098179  18/05/2015   85  410  N14  10/10/2017
#
#     fecha_rep                                            observs  No_Glosas  \
# 0  05/01/2018  GN0031(RC|1222129786|PINEDA|BONILLA|NATALY||S|...          1
# 1  05/01/2018  GN0031(RC|1118204206|CARRILLO|MORENO|MARIA|JOS...          1
# 2  05/01/2018  GN0032(S|EPS025|20/09/2017|85|136|F|AF|28/12/2...          1
# 3  05/01/2018  GN0130(F|RE|10/10/2017);GN0088(F|RE|10/10/2017...          3
# 4  05/01/2018  GN0130(F|RE|10/10/2017);GN0088(F|RE|10/10/2017...          3
#
#   observaciones_split                                           obs_glos
# 0              GN0031  (RC|1222129786|PINEDA|BONILLA|NATALY||S|EPS025...
# 1              GN0031  (RC|1118204206|CARRILLO|MORENO|MARIA|JOSE|S|EP...
# 2              GN0032       (S|EPS025|20/09/2017|85|136|F|AF|28/12/2017)
# 3              GN0130                                  (F|RE|10/10/2017)
# 4              GN0088                                  (F|RE|10/10/2017)

# %% [markdown]
# # Tamaño de dataframes

# %%
print('Name Row  Cols')
for name, df in dataframes.items():
    print(f"{name}: {df.shape}")
# Out:
# Name Row  Cols
# df_1: (40718, 13)
# df_2: (19646, 13)
# df_3: (13556, 13)
# df_4: (40294, 13)
# df_5: (6812, 13)
# df_6: (16144, 13)
# df_7: (9275, 13)

# %%
# Mostrar los tipos de datos de cada DataFrame en el diccionario
for name, df in dataframes.items():
    print(f"Tipos de datos del DataFrame '{name}':")
    print(df.dtypes)
    print("-" * 40)  # Separador para mayor claridad
# Out:
# Tipos de datos del DataFrame 'df_1':
# cod_reg                object
# tip_doc                object
# doc                    object
# fech_nac               object
# dep                     int64
# mun                     int64
# nov                    object
# fech_nov               object
# fecha_rep              object
# observs                object
# No_Glosas               int64
# observaciones_split    object
# obs_glos               object
# dtype: object
# ----------------------------------------
# Tipos de datos del DataFrame 'df_2':
# cod_reg                object
# tip_doc                object
# doc                    object
# fech_nac               object
# dep                     int64
# mun                     int64
# nov                    object
# fech_nov               object
# fecha_rep              object
# observs                object
# No_Glosas               int64
# observaciones_split    object
# obs_glos               object
# dtype: object
# ----------------------------------------
# Tipos de datos del DataFrame 'df_3':
# cod_reg                object
# tip_doc                object
# doc                    object
# fech_nac               object
# dep                     int64
# mun                     int64
# nov                    object
# fech_nov               object
# fecha_rep              object
# observs                object
# No_Glosas               int64
# observaciones_split    object
# obs_glos               object
# dtype: object
# ----------------------------------------
# Tipos de datos del DataFrame 'df_4':
# cod_reg                object
# tip_doc                object
# doc                    object
# fech_nac               object
# dep                     int64
# mun                     int64
# nov                    object
# fech_nov               object
# fecha_rep              object
# observs                object
# No_Glosas               int64
# observaciones_split    object
# obs_glos               object
# dtype: object
# ----------------------------------------
# Tipos de datos del DataFrame 'df_5':
# cod_reg                object
# tip_doc                object
# doc                    object
# fech_nac               object
# dep                     int64
# mun                     int64
# nov                    object
# fech_nov               object
# fecha_rep              object
# observs                object
# No_Glosas               int64
# observaciones_split    object
# obs_glos               object
# dtype: object
# ----------------------------------------
# Tipos de datos del DataFrame 'df_6':
# cod_reg                object
# tip_doc                object
# doc                    object
# fech_nac               object
# dep                     int64
# mun                     int64
# nov                    object
# fech_nov               object
# fecha_rep              object
# observs                object
# No_Glosas               int64
# observaciones_split    object
# obs_glos               object
# dtype: object
# ----------------------------------------
# Tipos de datos del DataFrame 'df_7':
# cod_reg                object
# tip_doc                object
# doc                    object
# fech_nac               object
# dep                     int64
# mun                     int64
# nov                    object
# fech_nov               object
# fecha_rep              object
# observs                object
# No_Glosas               int64
# observaciones_split    object
# obs_glos               object
# dtype: object
# ----------------------------------------

# %%
# Mostrar tipos de datos y porcentaje de nulos para cada DataFrame en el diccionario
for name, df in dataframes.items():
    print(f"Análisis del DataFrame '{name}':")
    # Porcentaje de nulos
    print("\nPorcentaje de valores nulos por columna:")
    porcentaje_nulos = df.isnull().mean() * 100  # Calcula el % de nulos
    print(porcentaje_nulos.round(2))  # Redondea a 2 decimales
    
    print("-" * 50)  # Separador para mayor claridad
# Out:
# Análisis del DataFrame 'df_1':
#
# Porcentaje de valores nulos por columna:
# cod_reg                0.00
# tip_doc                0.00
# doc                    0.00
# fech_nac               0.00
# dep                    0.00
# mun                    0.00
# nov                    0.00
# fech_nov               0.00
# fecha_rep              0.00
# observs                0.00
# No_Glosas              0.00
# observaciones_split    0.00
# obs_glos               8.65
# dtype: float64
# --------------------------------------------------
# Análisis del DataFrame 'df_2':
#
# Porcentaje de valores nulos por columna:
# cod_reg                 0.00
# tip_doc                 0.00
# doc                     0.00
# fech_nac                0.00
# dep                     0.00
# mun                     0.00
# nov                     0.00
# fech_nov                0.00
# fecha_rep               0.00
# observs                 0.00
# No_Glosas               0.00
# observaciones_split     0.00
# obs_glos               28.79
# dtype: float64
# --------------------------------------------------
# Análisis del DataFrame 'df_3':
#
# Porcentaje de valores nulos por columna:
# cod_reg                 0.0
# tip_doc                 0.0
# doc                     0.0
# fech_nac                0.0
# dep                     0.0
# mun                     0.0
# nov                     0.0
# fech_nov                0.0
# fecha_rep               0.0
# observs                 0.0
# No_Glosas               0.0
# observaciones_split     0.0
# obs_glos               27.7
# dtype: float64
# --------------------------------------------------
# Análisis del DataFrame 'df_4':
#
# Porcentaje de valores nulos por columna:
# cod_reg                0.00
# tip_doc                0.00
# doc                    0.00
# fech_nac               0.00
# dep                    0.00
# mun                    0.00
# nov                    0.00
# fech_nov               0.00
# fecha_rep              0.00
# observs                0.00
# No_Glosas              0.00
# observaciones_split    0.00
# obs_glos               1.83
# dtype: float64
# --------------------------------------------------
# Análisis del DataFrame 'df_5':
#
# Porcentaje de valores nulos por columna:
# cod_reg                0.00
# tip_doc                0.00
# doc                    0.00
# fech_nac               0.00
# dep                    0.00
# mun                    0.00
# nov                    0.00
# fech_nov               0.00
# fecha_rep              0.00
# observs                0.00
# No_Glosas              0.00
# observaciones_split    0.00
# obs_glos               5.24
# dtype: float64
# --------------------------------------------------
# Análisis del DataFrame 'df_6':
#
# Porcentaje de valores nulos por columna:
# cod_reg                0.00
# tip_doc                0.00
# doc                    0.00
# fech_nac               0.00
# dep                    0.00
# mun                    0.00
# nov                    0.00
# fech_nov               0.00
# fecha_rep              0.00
# observs                0.00
# No_Glosas              0.00
# observaciones_split    0.00
# obs_glos               1.81
# dtype: float64
# --------------------------------------------------
# Análisis del DataFrame 'df_7':
#
# Porcentaje de valores nulos por columna:
# cod_reg                0.00
# tip_doc                0.00
# doc                    0.00
# fech_nac               0.00
# dep                    0.00
# mun                    0.00
# nov                    0.00
# fech_nov               0.00
# fecha_rep              0.00
# observs                0.00
# No_Glosas              0.00
# observaciones_split    0.00
# obs_glos               6.34
# dtype: float64
# --------------------------------------------------

# %% [markdown]
# # 4. Merged Final

# %%
# Definir el número de columnas deseadas
num_columnas = 13

# Asegurar que todos los DataFrames tengan exactamente el mismo número de columnas
dataframes_alineados = {name: df.iloc[:, :num_columnas] for name, df in dataframes.items()}

# Preguntar al usuario cómo desea llamar al DataFrame combinado
#nombre_merged = input("¿Cómo deseas llamar al DataFrame combinado? ")

# Combinar todos los DataFrames alineados, sin crear nuevas columnas
globals()[nombre_merged] = pd.concat(dataframes_alineados.values(), axis=0, ignore_index=True)

# Mostrar el shape del DataFrame combinado
print(f"Shape del DataFrame '{nombre_merged}': {globals()[nombre_merged].shape}")

# Verificar las primeras filas
print(f"Primeras 5 filas del DataFrame '{nombre_merged}':")
print(globals()[nombre_merged].head())
# Out:
# Shape del DataFrame 'pruebas': (146445, 13)
# Primeras 5 filas del DataFrame 'pruebas':
#   cod_reg tip_doc        doc    fech_nac  dep  mun  nov    fech_nov  \
# 0  EPS025      CN  140637155  14/07/2017   85    1  N01  24/07/2017
# 1  EPS025      CN  131329379  13/08/2017   85  440  N01  31/08/2017
# 2  EPS025      CN  141596996  19/09/2017   85  136  N09  20/09/2017
# 3  EPS025      CN  128098179  18/05/2015   85  410  N14  10/10/2017
# 4  EPS025      CN  128098179  18/05/2015   85  410  N14  10/10/2017
#
#     fecha_rep                                            observs  No_Glosas  \
# 0  05/01/2018  GN0031(RC|1222129786|PINEDA|BONILLA|NATALY||S|...          1
# 1  05/01/2018  GN0031(RC|1118204206|CARRILLO|MORENO|MARIA|JOS...          1
# 2  05/01/2018  GN0032(S|EPS025|20/09/2017|85|136|F|AF|28/12/2...          1
# 3  05/01/2018  GN0130(F|RE|10/10/2017);GN0088(F|RE|10/10/2017...          3
# 4  05/01/2018  GN0130(F|RE|10/10/2017);GN0088(F|RE|10/10/2017...          3
#
#   observaciones_split                                           obs_glos
# 0              GN0031  (RC|1222129786|PINEDA|BONILLA|NATALY||S|EPS025...
# 1              GN0031  (RC|1118204206|CARRILLO|MORENO|MARIA|JOSE|S|EP...
# 2              GN0032       (S|EPS025|20/09/2017|85|136|F|AF|28/12/2017)
# 3              GN0130                                  (F|RE|10/10/2017)
# 4              GN0088                                  (F|RE|10/10/2017)

# %%
globals()[nombre_merged] .head(2)
# Out:
#   cod_reg tip_doc        doc    fech_nac  dep  mun  nov    fech_nov  \
# 0  EPS025      CN  140637155  14/07/2017   85    1  N01  24/07/2017
# 1  EPS025      CN  131329379  13/08/2017   85  440  N01  31/08/2017
#
#     fecha_rep                                            observs  No_Glosas  \
# 0  05/01/2018  GN0031(RC|1222129786|PINEDA|BONILLA|NATALY||S|...          1
# 1  05/01/2018  GN0031(RC|1118204206|CARRILLO|MORENO|MARIA|JOS...          1
#
#   observaciones_split                                           obs_glos
# 0              GN0031  (RC|1222129786|PINEDA|BONILLA|NATALY||S|EPS025...
# 1              GN0031  (RC|1118204206|CARRILLO|MORENO|MARIA|JOSE|S|EP...

# %%
globals()[nombre_merged] .dtypes
# Out:
# cod_reg                object
# tip_doc                object
# doc                    object
# fech_nac               object
# dep                     int64
# mun                     int64
# nov                    object
# fech_nov               object
# fecha_rep              object
# observs                object
# No_Glosas               int64
# observaciones_split    object
# obs_glos               object
# dtype: object

# %%
# Ruta para guardar en Descargas (Windows)
#output_path = os.path.expanduser("~/Downloads/merged_18_24.xlsx")

# Guardar el DataFrame
globals()[nombre_merged] .to_excel(output_path, index=False, engine='openpyxl')

print(f"El archivo se ha guardado correctamente en: {output_path}")
# Out:
# El archivo se ha guardado correctamente en: C:\Users\carlo\Downloads\pruebas.xlsx
